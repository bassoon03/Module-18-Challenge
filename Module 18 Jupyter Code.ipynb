# %%
import pandas as pd
from datetime import datetime

# %%
file1 = pd.read_csv('Module 18 Challenge\JC-202401-citibike-tripdata.csv')
file2 = pd.read_csv('Module 18 Challenge\JC-202402-citibike-tripdata.csv')
file3 = pd.read_csv('Module 18 Challenge\JC-202403-citibike-tripdata.csv')
new_file = pd.read_csv('Module 18 Challenge\JC-202304-citibike-tripdata.csv')

# %%
jan_2024_df = pd.DataFrame(file1)
feb_2024_df = pd.DataFrame(file2)
mar_2024_df = pd.DataFrame(file3)
new_file_df = pd.DataFrame(new_file)

# %%
new_file_df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      59B1078FC3455D5B  electric_bike  2023-04-02 14:50:55
# 1      84365D599B6E002E  electric_bike  2023-04-15 21:08:54
# 2      A4F033EAA7810781   classic_bike  2023-04-17 10:35:11
# 3      E9051DFD91E516BF   classic_bike  2023-04-07 12:19:31
# 4      0F6D86AEC1B29205   classic_bike  2023-04-07 12:28:21
# ...                 ...            ...                  ...
# 80683  DB10C78061D8DE72  electric_bike  2023-04-04 19:58:21
# 80684  540F192D0FEF0DCE   classic_bike  2023-04-14 18:46:17
# 80685  74353C7251042C05   classic_bike  2023-04-04 20:16:23
# 80686  F4B95B8815759FEF  electric_bike  2023-04-25 16:34:56
# 80687  46E6A207C37D3567  electric_bike  2023-04-09 09:56:42
#
#                   ended_at start_station_name start_station_id  \
# 0      2023-04-02 15:01:24      Hamilton Park            JC009
# 1      2023-04-16 10:54:44      Hamilton Park            JC009
# ...

# %%
jan_2024_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  0744109F13385D1D  electric_bike  2024-01-15 15:18:07  2024-01-15 15:32:44
# 1  B1488BFEF9118000   classic_bike  2024-01-13 15:32:50  2024-01-13 15:36:18
# 2  95A2FE8E51B4C836   classic_bike  2024-01-19 13:11:00  2024-01-19 13:14:44
# 3  95D9AFF6A1652DC1   classic_bike  2024-01-23 07:03:49  2024-01-23 07:07:11
# 4  5F7408988A83B1B3   classic_bike  2024-01-01 16:46:10  2024-01-01 16:50:31
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0       Morris Canal            JC072      Oakland Ave          JC022
# 1  JC Medical Center            JC110    Grove St PATH          JC115
# 2       Morris Canal            JC072      Exchange Pl          JC116
# 3       Morris Canal            JC072      Exchange Pl          JC116
# 4       Morris Canal            JC072       Harborside          JC104
#
#    start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
feb_2024_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  A841EF9C3617E47B  electric_bike  2024-02-12 16:17:19  2024-02-12 16:23:24
# 1  514881A61CAD0A93  electric_bike  2024-02-04 15:04:16  2024-02-04 15:40:14
# 2  511F37086CCC4510  electric_bike  2024-02-16 16:23:16  2024-02-16 16:27:16
# 3  27A2AA8BDD0D1F6E   classic_bike  2024-02-25 17:05:01  2024-02-25 17:10:53
# 4  2808ABEC0903C18E  electric_bike  2024-02-29 15:21:15  2024-02-29 15:26:03
#
#        start_station_name start_station_id            end_station_name  \
# 0         Adams St & 2 St            HB407  Stevens - River Ter & 6 St
# 1         Adams St & 2 St            HB407  Stevens - River Ter & 6 St
# 2  Clinton St & Newark St            HB409  Stevens - River Ter & 6 St
# 3         Adams St & 2 St            HB407  Stevens - River Ter & 6 St
# 4         Adams St & 2 St            HB407  Stevens - River Ter & 6 St
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
mar_2024_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  9F5EEFB7CF78C6EA  electric_bike  2024-03-21 13:32:42  2024-03-21 13:35:42
# 1  01E2E1F218F9D303  electric_bike  2024-03-16 08:26:15  2024-03-16 08:47:53
# 2  C2914D662B33AA55  electric_bike  2024-03-15 15:17:36  2024-03-15 15:32:12
# 3  6723F7CE51888493  electric_bike  2024-03-13 08:34:26  2024-03-13 08:50:08
# 4  EAB7E29AAB546941  electric_bike  2024-03-15 15:37:58  2024-03-15 16:19:32
#
#            start_station_name start_station_id  \
# 0  Stevens - River Ter & 6 St            HB602
# 1              Pershing Field            JC024
# 2              Pershing Field            JC024
# 3              Pershing Field            JC024
# 4              Pershing Field            JC024
#
#                    end_station_name end_station_id  start_lat  start_lng  \
# 0  City Hall - Washington St & 1 St          HB105  40.743143 -74.026907
# ...

# %%
quarter1_df = pd.concat([jan_2024_df, feb_2024_df, mar_2024_df])
quarter1_df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      0744109F13385D1D  electric_bike  2024-01-15 15:18:07
# 1      B1488BFEF9118000   classic_bike  2024-01-13 15:32:50
# 2      95A2FE8E51B4C836   classic_bike  2024-01-19 13:11:00
# 3      95D9AFF6A1652DC1   classic_bike  2024-01-23 07:03:49
# 4      5F7408988A83B1B3   classic_bike  2024-01-01 16:46:10
# ...                 ...            ...                  ...
# 65576  71034305DEC4E3AB   classic_bike  2024-03-27 17:40:07
# 65577  52BD7EF18DBD0557   classic_bike  2024-03-15 17:25:05
# 65578  376A4B66DD546551   classic_bike  2024-03-14 22:42:14
# 65579  63F3690F5A7D58D4   classic_bike  2024-03-08 16:47:01
# 65580  6E87C99CDDA7FCE4  electric_bike  2024-03-24 11:49:27
#
#                   ended_at start_station_name start_station_id  \
# 0      2024-01-15 15:32:44       Morris Canal            JC072
# 1      2024-01-13 15:36:18  JC Medical Center            JC110
# ...

# %%
new_file_df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
quarter1_df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
new_file_df['started_at'] = pd.to_datetime(new_file_df['started_at'])
new_file_df['ended_at'] = pd.to_datetime(new_file_df['ended_at'])

# %%
new_file_df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at            datetime64[ns]
# ended_at              datetime64[ns]
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# dtype: object

# %%
quarter1_df['started_at'] = pd.to_datetime(quarter1_df['started_at'])
quarter1_df['ended_at'] = pd.to_datetime(quarter1_df['ended_at'])

# %%
quarter1_df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at            datetime64[ns]
# ended_at              datetime64[ns]
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# dtype: object

# %%
# Saturn Cloud
new_file_df['Trip Duration (seconds)'] = (new_file_df["ended_at"] - new_file_df["started_at"]).dt.seconds
new_file_df
# Out:
#                 ride_id  rideable_type          started_at  \
# 0      59B1078FC3455D5B  electric_bike 2023-04-02 14:50:55
# 1      84365D599B6E002E  electric_bike 2023-04-15 21:08:54
# 2      A4F033EAA7810781   classic_bike 2023-04-17 10:35:11
# 3      E9051DFD91E516BF   classic_bike 2023-04-07 12:19:31
# 4      0F6D86AEC1B29205   classic_bike 2023-04-07 12:28:21
# ...                 ...            ...                 ...
# 80683  DB10C78061D8DE72  electric_bike 2023-04-04 19:58:21
# 80684  540F192D0FEF0DCE   classic_bike 2023-04-14 18:46:17
# 80685  74353C7251042C05   classic_bike 2023-04-04 20:16:23
# 80686  F4B95B8815759FEF  electric_bike 2023-04-25 16:34:56
# 80687  46E6A207C37D3567  electric_bike 2023-04-09 09:56:42
#
#                  ended_at start_station_name start_station_id  \
# 0     2023-04-02 15:01:24      Hamilton Park            JC009
# 1     2023-04-16 10:54:44      Hamilton Park            JC009
# 2     2023-04-17 10:37:53      Hamilton Park            JC009
# ...

# %%
# Saturn Cloud
quarter1_df['Trip Duration (seconds)'] = (quarter1_df["ended_at"] - quarter1_df["started_at"]).dt.seconds
quarter1_df
# Out:
#                 ride_id  rideable_type          started_at  \
# 0      0744109F13385D1D  electric_bike 2024-01-15 15:18:07
# 1      B1488BFEF9118000   classic_bike 2024-01-13 15:32:50
# 2      95A2FE8E51B4C836   classic_bike 2024-01-19 13:11:00
# 3      95D9AFF6A1652DC1   classic_bike 2024-01-23 07:03:49
# 4      5F7408988A83B1B3   classic_bike 2024-01-01 16:46:10
# ...                 ...            ...                 ...
# 65576  71034305DEC4E3AB   classic_bike 2024-03-27 17:40:07
# 65577  52BD7EF18DBD0557   classic_bike 2024-03-15 17:25:05
# 65578  376A4B66DD546551   classic_bike 2024-03-14 22:42:14
# 65579  63F3690F5A7D58D4   classic_bike 2024-03-08 16:47:01
# 65580  6E87C99CDDA7FCE4  electric_bike 2024-03-24 11:49:27
#
#                  ended_at start_station_name start_station_id  \
# 0     2024-01-15 15:32:44       Morris Canal            JC072
# 1     2024-01-13 15:36:18  JC Medical Center            JC110
# 2     2024-01-19 13:14:44       Morris Canal            JC072
# ...

# %%
new_file_df.sort_values(by = ['started_at'], inplace = True)
new_file_df
# Out:
#                 ride_id  rideable_type          started_at  \
# 30898  8519841A9CD3EAD9  electric_bike 2023-04-01 00:00:54
# 58395  AEECD9E6B391F964   classic_bike 2023-04-01 00:02:00
# 77945  C9D8BCB0EC5E8E50   classic_bike 2023-04-01 00:02:43
# 47560  2BFEFAAD3D0D0256   classic_bike 2023-04-01 00:02:56
# 47669  CE305DF6F95127F5  electric_bike 2023-04-01 00:03:01
# ...                 ...            ...                 ...
# 45671  65D10BA403FB7DD2   classic_bike 2023-04-30 23:24:28
# 37805  4DFE5CA502F7D2E7   classic_bike 2023-04-30 23:33:40
# 25719  5D21E8B6F8B17309   classic_bike 2023-04-30 23:37:07
# 78112  543FCF3F2B08E48A   classic_bike 2023-04-30 23:47:39
# 12819  7F94A8BC27565C40  electric_bike 2023-04-30 23:48:11
#
#                  ended_at                 start_station_name start_station_id  \
# 30898 2023-04-01 00:42:17               12 St & Sinatra Dr N            HB201
# 58395 2023-04-01 00:12:35  Columbus Park - Clinton St & 9 St            HB501
# ...

# %%
quarter1_df.sort_values(by = ['started_at'], inplace = True)
quarter1_df
# Out:
#                 ride_id  rideable_type          started_at  \
# 46102  A51F9BDD9A1D6299   classic_bike 2024-01-01 00:06:21
# 48909  D35D257404F7FC4B  electric_bike 2024-01-01 00:07:37
# 6835   38677F2D17A2B5A1  electric_bike 2024-01-01 00:08:26
# 25203  D25689277AF763BC   classic_bike 2024-01-01 00:08:36
# 27855  2ED1774EBF339BA4  electric_bike 2024-01-01 00:08:44
# ...                 ...            ...                 ...
# 62237  363FBA0A405C0B66  electric_bike 2024-03-31 23:56:19
# 46094  6FF7EAAFB41D911E   classic_bike 2024-03-31 23:58:04
# 36810  176F521C68C04ABF   classic_bike 2024-03-31 23:58:42
# 42062  14FDCBF3B3916BB9   classic_bike 2024-03-31 23:58:44
# 15493  222B9D316079C874  electric_bike 2024-03-31 23:59:35
#
#                  ended_at                            start_station_name  \
# 46102 2024-01-01 00:12:12                              Essex Light Rail
# 48909 2024-01-01 00:07:40                                   Exchange Pl
# ...

# %%
new_file_df = new_file_df[new_file_df['Trip Duration (seconds)'] > 60]
new_file_df
# Out:
#                 ride_id  rideable_type          started_at  \
# 30898  8519841A9CD3EAD9  electric_bike 2023-04-01 00:00:54
# 58395  AEECD9E6B391F964   classic_bike 2023-04-01 00:02:00
# 77945  C9D8BCB0EC5E8E50   classic_bike 2023-04-01 00:02:43
# 47560  2BFEFAAD3D0D0256   classic_bike 2023-04-01 00:02:56
# 47669  CE305DF6F95127F5  electric_bike 2023-04-01 00:03:01
# ...                 ...            ...                 ...
# 45671  65D10BA403FB7DD2   classic_bike 2023-04-30 23:24:28
# 37805  4DFE5CA502F7D2E7   classic_bike 2023-04-30 23:33:40
# 25719  5D21E8B6F8B17309   classic_bike 2023-04-30 23:37:07
# 78112  543FCF3F2B08E48A   classic_bike 2023-04-30 23:47:39
# 12819  7F94A8BC27565C40  electric_bike 2023-04-30 23:48:11
#
#                  ended_at                 start_station_name start_station_id  \
# 30898 2023-04-01 00:42:17               12 St & Sinatra Dr N            HB201
# 58395 2023-04-01 00:12:35  Columbus Park - Clinton St & 9 St            HB501
# ...

# %%
quarter1_df = quarter1_df[quarter1_df['Trip Duration (seconds)'] > 60]
quarter1_df
# Out:
#                 ride_id  rideable_type          started_at  \
# 46102  A51F9BDD9A1D6299   classic_bike 2024-01-01 00:06:21
# 6835   38677F2D17A2B5A1  electric_bike 2024-01-01 00:08:26
# 25203  D25689277AF763BC   classic_bike 2024-01-01 00:08:36
# 27855  2ED1774EBF339BA4  electric_bike 2024-01-01 00:08:44
# 40078  C06E0860F8AA9ED8   classic_bike 2024-01-01 00:09:17
# ...                 ...            ...                 ...
# 62237  363FBA0A405C0B66  electric_bike 2024-03-31 23:56:19
# 46094  6FF7EAAFB41D911E   classic_bike 2024-03-31 23:58:04
# 36810  176F521C68C04ABF   classic_bike 2024-03-31 23:58:42
# 42062  14FDCBF3B3916BB9   classic_bike 2024-03-31 23:58:44
# 15493  222B9D316079C874  electric_bike 2024-03-31 23:59:35
#
#                  ended_at                            start_station_name  \
# 46102 2024-01-01 00:12:12                              Essex Light Rail
# 6835  2024-01-01 00:24:29                                   Exchange Pl
# ...

# %%
new_file_df.dropna(how = 'any', inplace = True)
new_file_df = new_file_df.reset_index()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_2712\1912075663.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_file_df.dropna(how = 'any', inplace = True)

# %%
quarter1_df.dropna(how = 'any', inplace = True)
quarter1_df = quarter1_df.reset_index()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_2712\792109299.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quarter1_df.dropna(how = 'any', inplace = True)

# %%
quarter1_df
# Out:
#         index           ride_id  rideable_type          started_at  \
# 0       46102  A51F9BDD9A1D6299   classic_bike 2024-01-01 00:06:21
# 1        6835  38677F2D17A2B5A1  electric_bike 2024-01-01 00:08:26
# 2       25203  D25689277AF763BC   classic_bike 2024-01-01 00:08:36
# 3       27855  2ED1774EBF339BA4  electric_bike 2024-01-01 00:08:44
# 4       40078  C06E0860F8AA9ED8   classic_bike 2024-01-01 00:09:17
# ...       ...               ...            ...                 ...
# 167509  62237  363FBA0A405C0B66  electric_bike 2024-03-31 23:56:19
# 167510  46094  6FF7EAAFB41D911E   classic_bike 2024-03-31 23:58:04
# 167511  36810  176F521C68C04ABF   classic_bike 2024-03-31 23:58:42
# 167512  42062  14FDCBF3B3916BB9   classic_bike 2024-03-31 23:58:44
# 167513  15493  222B9D316079C874  electric_bike 2024-03-31 23:59:35
#
#                   ended_at                            start_station_name  \
# 0      2024-01-01 00:12:12                              Essex Light Rail
# ...

# %%
start_popularity2 = new_file_df["start_station_name"].value_counts()
end_popularity2 = new_file_df["end_station_name"].value_counts()

start_popularity2 = pd.DataFrame(start_popularity2)
end_popularity2 = pd.DataFrame(end_popularity2)

#new_file_df = new_file_df.merge(start_popularity2, how = 'left', on = "start_station_name")
#new_file_df = new_file_df.merge(end_popularity2, how = 'left', on = "end_station_name")

new_file_df = new_file_df.rename(columns = {"count_x":"Start Station Popularity", "count_y":"End Station Popularity"})

new_file_df
# Out:
#        index           ride_id  rideable_type          started_at  \
# 0      30898  8519841A9CD3EAD9  electric_bike 2023-04-01 00:00:54
# 1      58395  AEECD9E6B391F964   classic_bike 2023-04-01 00:02:00
# 2      77945  C9D8BCB0EC5E8E50   classic_bike 2023-04-01 00:02:43
# 3      47560  2BFEFAAD3D0D0256   classic_bike 2023-04-01 00:02:56
# 4      47669  CE305DF6F95127F5  electric_bike 2023-04-01 00:03:01
# ...      ...               ...            ...                 ...
# 78421  45671  65D10BA403FB7DD2   classic_bike 2023-04-30 23:24:28
# 78422  37805  4DFE5CA502F7D2E7   classic_bike 2023-04-30 23:33:40
# 78423  25719  5D21E8B6F8B17309   classic_bike 2023-04-30 23:37:07
# 78424  78112  543FCF3F2B08E48A   classic_bike 2023-04-30 23:47:39
# 78425  12819  7F94A8BC27565C40  electric_bike 2023-04-30 23:48:11
#
#                  ended_at                 start_station_name start_station_id  \
# 0     2023-04-01 00:42:17               12 St & Sinatra Dr N            HB201
# ...

# %%
start_popularity = quarter1_df["start_station_name"].value_counts()
end_popularity = quarter1_df["end_station_name"].value_counts()

start_popularity = pd.DataFrame(start_popularity)
end_popularity = pd.DataFrame(end_popularity)

# quarter1_df = quarter1_df.merge(start_popularity, how = 'left', on = "start_station_name")
# quarter1_df = quarter1_df.merge(end_popularity, how = 'left', on = "end_station_name")


quarter1_df = quarter1_df.rename(columns = {"count_x":"Start Station Popularity", "count_y":"End Station Popularity"})

quarter1_df
# Out:
#         index           ride_id  rideable_type          started_at  \
# 0       46102  A51F9BDD9A1D6299   classic_bike 2024-01-01 00:06:21
# 1        6835  38677F2D17A2B5A1  electric_bike 2024-01-01 00:08:26
# 2       25203  D25689277AF763BC   classic_bike 2024-01-01 00:08:36
# 3       27855  2ED1774EBF339BA4  electric_bike 2024-01-01 00:08:44
# 4       40078  C06E0860F8AA9ED8   classic_bike 2024-01-01 00:09:17
# ...       ...               ...            ...                 ...
# 167509  62237  363FBA0A405C0B66  electric_bike 2024-03-31 23:56:19
# 167510  46094  6FF7EAAFB41D911E   classic_bike 2024-03-31 23:58:04
# 167511  36810  176F521C68C04ABF   classic_bike 2024-03-31 23:58:42
# 167512  42062  14FDCBF3B3916BB9   classic_bike 2024-03-31 23:58:44
# 167513  15493  222B9D316079C874  electric_bike 2024-03-31 23:59:35
#
#                   ended_at                            start_station_name  \
# 0      2024-01-01 00:12:12                              Essex Light Rail
# ...

# %%
new_file_df.to_csv('C:\\Users\\Owner\\OneDrive\\Module 18 Challenge\\CitiBikeJC202404.csv')

# %%
quarter1_df.to_csv('C:\\Users\\Owner\\OneDrive\\Module 18 Challenge\\CitiBike2024.csv')
